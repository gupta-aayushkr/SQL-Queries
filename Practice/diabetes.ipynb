-- %%
use practice;
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00

-- %%
select * from diabetes;
-- Out:
-- (768 row(s) affected)
-- Total execution time: 00:00:01.008
-- ...

-- %%
describe diabetes;
-- Out:
-- (9 row(s) affected)
-- Total execution time: 00:00:01.010
-- ...

-- %%
SELECT AVG(Glucose) AS Average_Glucose FROM diabetes;
-- Out:
-- (1 row(s) affected)
-- Total execution time: 00:00:01.006
-- <table><tr><th>Average_Glucose</th></tr><tr><td>120.8945</td></tr></table>

-- %%
SELECT COUNT(*) AS Count_BMI_Greater_30 FROM diabetes WHERE BMI > 30;
-- Out:
-- (1 row(s) affected)
-- Total execution time: 00:00:01.010
-- <table><tr><th>Count_BMI_Greater_30</th></tr><tr><td>465</td></tr></table>

-- %%
SELECT MAX(BloodPressure) AS Max_BloodPressure FROM diabetes;
-- Out:
-- (1 row(s) affected)
-- Total execution time: 00:00:01.007
-- <table><tr><th>Max_BloodPressure</th></tr><tr><td>122</td></tr></table>

-- %%
SELECT MAX(BloodPressure) AS Max_BloodPressure FROM diabetes;
-- Out:
-- (1 row(s) affected)
-- Total execution time: 00:00:01.007
-- <table><tr><th>Max_BloodPressure</th></tr><tr><td>122</td></tr></table>

-- %%
SELECT * FROM diabetes WHERE Age BETWEEN 20 AND 30;
-- Out:
-- (417 row(s) affected)
-- Total execution time: 00:00:01.007
-- ...

-- %%
SELECT SUM(Pregnancies) AS Total_Pregnancies FROM diabetes;
-- Out:
-- (1 row(s) affected)
-- Total execution time: 00:00:01.008
-- <table><tr><th>Total_Pregnancies</th></tr><tr><td>2953</td></tr></table>

-- %%
SELECT * FROM diabetes WHERE Outcome = 1 AND BMI > 35;
-- Out:
-- (115 row(s) affected)
-- Total execution time: 00:00:01.007
-- ...

-- %%
SELECT AVG(DiabetesPedigreeFunction) AS Average_DiabetesPedigreeFunction
FROM diabetes
WHERE Outcome = 1;
-- Out:
-- (1 row(s) affected)
-- Total execution time: 00:00:01.004
-- <table><tr><th>Average_DiabetesPedigreeFunction</th></tr><tr><td>0.5505</td></tr></table>

-- %%
SELECT * FROM diabetes WHERE Insulin IS NULL;
-- Out:
-- (0 row(s) affected)
-- Total execution time: 00:00:01.007
-- <table><tr><th>Pregnancies</th><th>Glucose</th><th>BloodPressure</th><th>SkinThickness</th><th>Insulin</th><th>BMI</th><th>DiabetesPedigreeFunction</th><th>Age</th><th>Outcome</th></tr></table>
